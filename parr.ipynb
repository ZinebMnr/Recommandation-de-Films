# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
from concurrent.futures import ThreadPoolExecutor

headers = {"User-Agent": "Mozilla/5.0"}

def get_film_links(page):
    url = f"https://www.allocine.fr/films/?page={page}"
    resp = requests.get(url, headers=headers)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")
    links = [
        "https://www.allocine.fr" + a["href"]
        for a in soup.select("h2.meta-title a.meta-title-link")
        if a.get("href")
    ]
    return links

def get_film_info(link):
    try:
        resp_f = requests.get(link, headers=headers)
        resp_f.raise_for_status()
        fsoup = BeautifulSoup(resp_f.text, "html.parser")

        # Titre
        film_name = (
            fsoup.title.string.split(" - ")[0].strip()
            if fsoup.title and fsoup.title.string
            else None
        )

        # Synopsis
        syno_el = fsoup.select_one(".content-txt")
        film_synopsis = syno_el.get_text(strip=True) if syno_el else None

        # Genre(s)
        genre = None
        json_ld = fsoup.find("script", type="application/ld+json")
        if json_ld and json_ld.string:
            try:
                data = json.loads(json_ld.string)
                genre_data = data.get("genre")
                if isinstance(genre_data, list):
                    genre = ", ".join(genre_data)
                elif isinstance(genre_data, str):
                    genre = genre_data
            except json.JSONDecodeError:
                genre = None

        return {
            "name": film_name,
            "synopsis": film_synopsis,
            "genre": genre
        }

    except Exception as e:
        print(f"Erreur pour {link}: {e}")
        return None

def grab_info_parallel(total_pages=3, max_workers=10):
    print(f"Scraping les pages de liste (1 à {total_pages})...")
    all_links = []

    # Scrape tous les liens de films
    for page in range(1, total_pages + 1):
        links = get_film_links(page)
        print(f" → Page {page} : {len(links)} films trouvés.")
        all_links.extend(links)

    print(f"\n→ Total films à scraper : {len(all_links)}")

    # Scraping parallèle des pages de films
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        results = list(executor.map(get_film_info, all_links))

    # Nettoyage des résultats (None → erreurs)
    results = [film for film in results if film is not None]
    df = pd.DataFrame(results)
    return df


if __name__ == "__main__":
    df = grab_info_parallel(total_pages=670, max_workers=15)
    print(df.head())

    df.to_csv("films_allocine_parallelfinal.csv", index=False, encoding="utf-8-sig")
    print("→ CSV créé : films_allocine_parallel.csv")
# Out:
# Scraping les pages de liste (1 à 670)...
#  → Page 1 : 15 films trouvés.
#  → Page 2 : 15 films trouvés.
#  → Page 3 : 15 films trouvés.
#  → Page 4 : 15 films trouvés.
#  → Page 5 : 15 films trouvés.
#  → Page 6 : 15 films trouvés.
#  → Page 7 : 15 films trouvés.
#  → Page 8 : 15 films trouvés.
#  → Page 9 : 15 films trouvés.
#  → Page 10 : 15 films trouvés.
#  → Page 11 : 15 films trouvés.
#  → Page 12 : 15 films trouvés.
#  → Page 13 : 15 films trouvés.
#  → Page 14 : 15 films trouvés.
#  → Page 15 : 15 films trouvés.
#  → Page 16 : 15 films trouvés.
#  → Page 17 : 15 films trouvés.
#  → Page 18 : 15 films trouvés.
#  → Page 19 : 15 films trouvés.
#  → Page 20 : 15 films trouvés.
#  → Page 21 : 15 films trouvés.
#  → Page 22 : 15 films trouvés.
#  → Page 23 : 15 films trouvés.
#  → Page 24 : 15 films trouvés.
#  → Page 25 : 15 films trouvés.
#  → Page 26 : 15 films trouvés.
#  → Page 27 : 15 films trouvés.
#  → Page 28 : 15 films trouvés.
#  → Page 29 : 15 films trouvés.
#  → Page 30 : 15 films trouvés.
#  → Page 608 : 15 films trouvés.
#  → Page 609 : 15 films trouvés.
#  → Page 610 : 15 films trouvés.
#  → Page 611 : 15 films trouvés.
#  → Page 612 : 15 films trouvés.
#  → Page 613 : 15 films trouvés.
#  → Page 614 : 15 films trouvés.
#  → Page 615 : 15 films trouvés.
#  → Page 616 : 15 films trouvés.
#  → Page 617 : 15 films trouvés.
#  → Page 618 : 15 films trouvés.
#  → Page 619 : 15 films trouvés.
#  → Page 620 : 15 films trouvés.
#  → Page 621 : 15 films trouvés.
#  → Page 622 : 15 films trouvés.
#  → Page 623 : 15 films trouvés.
#  → Page 624 : 15 films trouvés.
#  → Page 625 : 15 films trouvés.
#  → Page 626 : 15 films trouvés.
#  → Page 627 : 15 films trouvés.
#  → Page 628 : 15 films trouvés.
#  → Page 629 : 15 films trouvés.
#  → Page 630 : 15 films trouvés.
#  → Page 631 : 15 films trouvés.
#  → Page 632 : 15 films trouvés.
#  → Page 633 : 15 films trouvés.
#  → Page 634 : 15 films trouvés.
#  → Page 635 : 15 films trouvés.
#  → Page 636 : 15 films trouvés.
#  → Page 637 : 15 films trouvés.
#  → Page 638 : 15 films trouvés.
#  → Page 639 : 15 films trouvés.
#  → Page 640 : 15 films trouvés.
#  → Page 641 : 15 films trouvés.
#  → Page 642 : 15 films trouvés.
#  → Page 643 : 15 films trouvés.
#  → Page 644 : 15 films trouvés.
#  → Page 645 : 15 films trouvés.
#  → Page 646 : 15 films trouvés.
#  → Page 647 : 15 films trouvés.
#  → Page 648 : 15 films trouvés.
#  → Page 649 : 15 films trouvés.
#  → Page 650 : 15 films trouvés.
#  → Page 651 : 15 films trouvés.
#  → Page 652 : 15 films trouvés.
#  → Page 653 : 15 films trouvés.
#  → Page 654 : 15 films trouvés.
#  → Page 655 : 15 films trouvés.
#  → Page 656 : 15 films trouvés.
#  → Page 657 : 15 films trouvés.
#  → Page 658 : 15 films trouvés.
#  → Page 659 : 15 films trouvés.
#  → Page 660 : 15 films trouvés.
#  → Page 661 : 15 films trouvés.
#  → Page 662 : 15 films trouvés.
#  → Page 663 : 15 films trouvés.
#  → Page 664 : 15 films trouvés.
#  → Page 665 : 15 films trouvés.
#  → Page 666 : 15 films trouvés.
#  → Page 667 : 15 films trouvés.
#  → Page 668 : 15 films trouvés.
#  → Page 669 : 15 films trouvés.
#  → Page 670 : 15 films trouvés.
#
# → Total films à scraper : 10050
#                              name  \
# 0  Ma Mère, Dieu et Sylvie Vartan
# 1                   Blanche Neige
# 2              Minecraft, Le Film
# 3                       Mickey 17
# 4                          On Ira
#
#                                             synopsis  \
# 0  En 1963, Esther met au monde Roland, petit der...
# 1  "Blanche-Neige" des studios Disney est une nou...
# 2  Bienvenue dans l’univers de Minecraft où la cr...
# 3  Héros malgré lui, Mickey Barnes se tue à la tâ...
# 4  Marie, 80 ans, en a ras le bol de sa maladie. ...
#
#                                      genre
# 0                       Comédie dramatique
# 1  Aventure, Fantastique, Comédie musicale
# 2               Aventure, Comédie, Famille
# 3         Action, Comédie, Science Fiction
# 4                       Comédie dramatique
# → CSV créé : films_allocine_parallel.csv
